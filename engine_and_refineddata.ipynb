# %%
import sqlalchemy as db
import psycopg2

# %%
from sqlalchemy import create_engine

engine = db.create_engine('postgresql://postgres:Cleocatra64!@localhost/climate_and_nocturnal_insects')
connection = engine.connect()
metadata = db.MetaData()
combined_data = db.Table('combined_data', metadata, autoload=True, autoload_with=engine)

# %%
print(combined_data.columns.keys())
# Out:
# ['order_name', 'family_name', 'scientific_name', 'datetime', 'individuals', 'location_name', 'tempmax', 'tempmin', 'temp_daily', 'humidity']

# %%
#print table metadata
print(repr(metadata.tables['combined_data']))
# Out:
# Table('combined_data', MetaData(), Column('order_name', VARCHAR(), table=<combined_data>, nullable=False), Column('family_name', VARCHAR(), table=<combined_data>, nullable=False), Column('scientific_name', VARCHAR(), table=<combined_data>, nullable=False), Column('datetime', DATE(), table=<combined_data>, nullable=False), Column('individuals', INTEGER(), table=<combined_data>, nullable=False), Column('location_name', VARCHAR(), table=<combined_data>, nullable=False), Column('tempmax', DOUBLE_PRECISION(precision=53), table=<combined_data>, nullable=False), Column('tempmin', DOUBLE_PRECISION(precision=53), table=<combined_data>, nullable=False), Column('temp_daily', DOUBLE_PRECISION(precision=53), table=<combined_data>, nullable=False), Column('humidity', DOUBLE_PRECISION(precision=53), table=<combined_data>, nullable=False), schema=None)

# %%
insect_data = db.Table('insects', metadata, autoload=True, autoload_with=engine)
weather_data=db.Table('weather', metadata, autoload=True, autoload_with=engine)

# %%
print(insect_data.columns.keys())
# Out:
# ['order_name', 'family_name', 'scientific_name', 'datetime', 'individuals']

# %%
print(weather_data.columns.keys())
# Out:
# ['location_name', 'datetime', 'tempmax', 'tempmin', 'temp_daily', 'humidity']

# %%
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(db)
session = Session()

# %%
import pandas as pd

# %%
engine = db.create_engine('postgresql://postgres:Cleocatra64!@localhost/climate_and_nocturnal_insects')
with engine.connect() as conn:
    dataframe = pd.read_sql("select * from all_dates", conn)
    #dataframe.to_sql()

# %%
pivot_df = dataframe.pivot_table(index="datetime", columns="family_name", values="individuals")

# %%
pivot_df
# Out:
# family_name  ACROLEPIIDAE  ADELIDAE  ADERIDAE  AGONOXENIDAE  ALUCITIDAE  \
# datetime
# 1992-06-23            NaN       NaN       NaN           1.0         NaN
# 1992-06-25            NaN       NaN       NaN           3.0         NaN
# 1992-06-28            NaN       NaN       NaN           1.0         NaN
# 1992-07-02            NaN       NaN       NaN           NaN         NaN
# 1992-07-05            NaN       NaN       NaN           NaN         NaN
# ...                   ...       ...       ...           ...         ...
# 2009-08-20            NaN       NaN       NaN           NaN         NaN
# 2009-08-25            NaN       NaN       NaN           NaN         NaN
# 2009-08-27            NaN       NaN       NaN           NaN         NaN
# 2009-08-31            NaN       NaN       NaN           NaN         NaN
# 2009-09-02            NaN       NaN       NaN           NaN         NaN
#
# family_name  AMPHISBATHIDAE  ANOBIIDAE  ANTHICIDAE  ARCTIIDAE  ATTELABIDAE  \
# datetime
# 1992-06-23              NaN        NaN         NaN        NaN          NaN
# 1992-06-25              NaN        NaN         NaN        NaN          NaN
# 1992-06-28              NaN        NaN         NaN        NaN          NaN
# 1992-07-02              NaN        NaN         NaN        1.0          NaN
# 1992-07-05              NaN        NaN         NaN        1.0          NaN
# ...                     ...        ...         ...        ...          ...
# 2009-08-20              NaN        NaN         NaN        NaN          NaN
# 2009-08-25              NaN        NaN         NaN        NaN          NaN
# 2009-08-27              NaN        NaN         NaN        NaN          NaN
# 2009-08-31              NaN        NaN         NaN        NaN          NaN
# 2009-09-02              NaN        NaN         NaN        NaN          NaN
#
# family_name  ...  SCRAPTIIDAE  SILPHIDAE  SPHINGIDAE  STAPHYLINIDAE  \
# datetime     ...
# 1992-06-23   ...          NaN        NaN         NaN            NaN
# 1992-06-25   ...          NaN        NaN         NaN            NaN
# 1992-06-28   ...          NaN        NaN         NaN            1.0
# 1992-07-02   ...          NaN        NaN         NaN            1.2
# 1992-07-05   ...          NaN        NaN         NaN            NaN
# ...          ...          ...        ...         ...            ...
# 2009-08-20   ...          NaN        NaN         NaN            NaN
# 2009-08-25   ...          1.0        NaN         NaN            1.0
# 2009-08-27   ...          NaN        NaN         NaN            1.0
# 2009-08-31   ...          NaN        NaN         NaN            NaN
# 2009-09-02   ...          NaN        NaN         NaN            NaN
#
# family_name  TENEBRIONIDAE  THROSCIDAE  TINEIDAE  TISCHERIIDAE  TORTRICIDAE  \
# datetime
# 1992-06-23             NaN         NaN       1.0           NaN     9.789474
# 1992-06-25             NaN         NaN       2.0           NaN    11.518519
# 1992-06-28             1.0         NaN       2.0           NaN    11.393939
# 1992-07-02             NaN         NaN       NaN           NaN     6.131579
# 1992-07-05             NaN         NaN       NaN           NaN     1.800000
# ...                    ...         ...       ...           ...          ...
# 2009-08-20             NaN         NaN       NaN           NaN     1.571429
# 2009-08-25             NaN         NaN       NaN           2.0     1.454545
# 2009-08-27             NaN         1.0       1.0           NaN     1.333333
# 2009-08-31             NaN         NaN       NaN           NaN     1.600000
# 2009-09-02             NaN         NaN       NaN           NaN          NaN
#
# family_name  YPONOMEUTIDAE
# datetime
# 1992-06-23        2.000000
# 1992-06-25        2.833333
# 1992-06-28        4.666667
# 1992-07-02        3.181818
# 1992-07-05        1.000000
# ...                    ...
# 2009-08-20        8.600000
# 2009-08-25       11.000000
# 2009-08-27        2.000000
# 2009-08-31        1.000000
# 2009-09-02        1.000000
#
# [577 rows x 104 columns]

# %%
engine = db.create_engine('postgresql://postgres:Cleocatra64!@localhost/climate_and_nocturnal_insects')
with engine.connect() as conn:
    pivot_df.to_sql('pivot_table', engine)
